# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ### Import data

# %%
force_old = pd.read_csv('./apr3/apr3-force-old.csv')
pressure_old = pd.read_csv('./apr3/apr3-pressure-old.csv')
force_new = pd.read_csv('./apr3/apr3-force-new.csv')
pressure_new = pd.read_csv('./apr3/apr3-pressure-new.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(pressure_old['Air Pressure'], label='Pressure')
ax1.plot(pressure_old['PWM'], label='PWM')
ax1.plot(force_old['Force (N)'], label='Force')
ax1.set(xlim=(0, 1600))
ax1.set(title='Old Pumps', xlabel='Time', ylabel='Air Pressure (mbar)')
ax1.legend()

ax2.plot(pressure_new['Air Pressure'], label='Pressure')
ax2.plot(pressure_new['PWM'], label='PWM')
ax2.set(title='New Pumps', xlabel='Time', ylabel='Air Pressure (mbar)')
ax2.legend()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(force_old['Force (N)'], label='Force')
ax1.plot(pressure_old['PWM'], label='PWM')
ax1.set(xlim=(0, 1050))
ax1.legend()

ax2.plot(force_new['Force (N)'], label='Force')
ax2.plot(force_new['PWM'], label='PWM')
ax2.set(xlim=(0, 1500))
ax2.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/syde556/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/syde556/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/syde556/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PWM'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(pressure_old['Air Pressure'].shape)
print(force_old['Force (N)'].shape)
print(force_new['Force (N)'].shape)
# Out:
# (4800,)
# (2841,)
# (3089,)
